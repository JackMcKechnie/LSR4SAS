# %%
import pandas as pd
import pyterrier as pt

# %%
results = pd.read_csv("./runs_wo_filter_v2/results_w_paths.csv")

# %%
for path in results["path"]:
    pt.io.read_results(path)
