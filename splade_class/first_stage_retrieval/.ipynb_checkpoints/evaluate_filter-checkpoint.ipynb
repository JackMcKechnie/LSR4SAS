# %%
import pandas as pd

# %%
results = pd.read_csv("./runs_wo_filter_v2/results_w_paths.csv")
results = results[results["name"].str.contains("filter")]
results[["name", "nDCG@10",	"sens_docs@10", "nCSDCG_cut_10"]].to_csv("filter_only_results.csv", index = False)
