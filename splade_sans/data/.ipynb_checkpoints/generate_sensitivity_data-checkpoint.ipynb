# %%
import pandas as pd
import json

# %%
full_df = pd.read_csv("./training_data_w_qids.csv")

# %%
full_df
# Out:
#         medline_ui                                              title  \
# 0         88000001  The binding of acetaldehyde to the active site...
# 1         88000002  Reductions in breath ethanol readings in norma...
# 2         88000003  Does the blockade of opioid receptors influenc...
# 3         88000006  Drinkwatchers--description of subjects and eva...
# 4         88000007  Platelet affinity for serotonin is increased i...
# ...            ...                                                ...
# 334065    87325749  Clinical investigation of Duchenne muscular dy...
# 334066    87325791  Prostaglandins. Old concepts and new perspecti...
# 334067    87325811  Vinculin in focal cell-to-substrate attachment...
# 334068    87325849  Intraocular fibrinolysis with recombinant huma...
# 334069    87326525  Peripheral blood and synovial fluid monocyte a...
#
#                                                  abstract  sensitivity  \
# ...

# %%
labels = {}
for _, row in full_df.iterrows():
    qid = str(row['qid'])
    doc_id = str(row['medline_ui'])
    label = int(row["sensitivity"])
    labels[doc_id] = label

# %%
full_df[full_df["medline_ui" == "90359960"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/miniconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 full_df[full_df["medline_ui" == "90359960"]]
#
# ...

# %%
# labels_path = "./sensitivity_labels.json"
# with open(labels_path, 'w') as json_file:
#     json.dump(labels, json_file, indent=4)

# %%
# queries = pd.read_csv("./training_queries.tsv", sep = "\t", columns [])
